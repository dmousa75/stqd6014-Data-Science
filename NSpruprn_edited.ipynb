# %% [markdown]
# <a href="https://colab.research.google.com/github/dmousa75/stqd6014-Data-Science/blob/main/NSpruprn_edited.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the data from drive

# %%
file_path = ('/content/drive/MyDrive/Analisa PRU/Keputusan PRU15_PRN15 NS_edited.csv')
df = pd.read_csv(file_path)

# %% [markdown]
# ## Wrangling the data

# %%
df.head()
# Out:
#    ID StatusPR  KodParlimen NamaParlimen   KodDUN  NamaDUN    KodDM  \
# 0   1    PRU15          126       JELEBU      NaN      NaN  1260000
# 1   2    PRN15          126       JELEBU  12601.0  CHENNAH  1260100
# 2   3    PRN15          126       JELEBU  12601.0  CHENNAH  1260100
# 3   4    PRN15          126       JELEBU  12601.0  CHENNAH  1260101
# 4   5    PRN15          126       JELEBU  12601.0  CHENNAH  1260101
#
#                NAMA PDM  No Saluran Jum Undi PRU_15  ... %UP_PH_prn15  \
# 0              UNDI POS         NaN           1,071  ...          NaN
# 1              UNDI POS         NaN             NaN  ...       31.20%
# 2             UNDI AWAL         1.0              21  ...       31.00%
# 3  KAMPONG SUNGAI BULOH         1.0             365  ...       49.20%
# 4  KAMPONG SUNGAI BULOH         2.0             419  ...       34.00%
#
#   %UP_PN_prn15 BN.1 PH.1 PN.1 JUM PENGUNDI (ALL KAUM) MELAYU CINA INDIA  \
# ...

# %%
df.tail()
# Out:
#         ID StatusPR  KodParlimen NamaParlimen   KodDUN NamaDUN    KodDM  \
# 1523  1567    PRN15          133       TAMPIN  13336.0   REPAH  1333608
# 1524  1568    PRN15          133       TAMPIN  13336.0   REPAH  1333608
# 1525  1569    PRN15          133       TAMPIN  13336.0   REPAH  1333608
# 1526  1570    PRN15          133       TAMPIN  13336.0   REPAH  1333608
# 1527  1571    PRN15          133       TAMPIN  13336.0   REPAH  1333608
#
#          NAMA PDM  No Saluran Jum Undi PRU_15  ... %UP_PH_prn15 %UP_PN_prn15  \
# 1523  TAMAN INDAH         2.0             665  ...       78.90%       21.10%
# 1524  TAMAN INDAH         3.0             812  ...       81.10%       18.90%
# 1525  TAMAN INDAH         4.0             460  ...       73.00%       27.00%
# 1526  TAMAN INDAH         5.0             439  ...       77.30%       22.70%
# 1527  TAMAN INDAH         6.0             499  ...       75.40%       24.60%
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1528 entries, 0 to 1527
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       1528 non-null   int64
#  1   StatusPR                 1528 non-null   object
#  2   KodParlimen              1528 non-null   int64
#  3   NamaParlimen             1528 non-null   object
#  4   KodDUN                   1520 non-null   float64
#  5   NamaDUN                  1520 non-null   object
#  6   KodDM                    1528 non-null   int64
#  7   NAMA PDM                 1528 non-null   object
#  8   No Saluran               1484 non-null   float64
#  9   Jum Undi PRU_15          1395 non-null   object
#  10  PARTI MENANG pru_15      1395 non-null   object
#  11  %UP_BN_pru15             1395 non-null   object
#  12  %UP_PH_pru15             1395 non-null   object
#  13  %UP_PN_pru15             1395 non-null   object
# ...

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['ID', 'StatusPR', 'KodParlimen', 'NamaParlimen', 'KodDUN', 'NamaDUN',
#        'KodDM', 'NAMA PDM', 'No Saluran', 'Jum Undi PRU_15',
#        'PARTI MENANG pru_15', '%UP_BN_pru15', '%UP_PH_pru15', '%UP_PN_pru15',
#        'BN', 'PH', 'PN', 'Jum Undi PRN_15', 'PARTI MENANG prn_15',
#        '%UP_BN_prn15', '%UP_PH_prn15', '%UP_PN_prn15', 'BN.1', 'PH.1', 'PN.1',
#        'JUM PENGUNDI (ALL KAUM)', 'MELAYU', 'CINA', 'INDIA', 'LAIN-LAIN'],
#       dtype='object')

# %% [markdown]
# # Grouping the columns from dataset

# %%
#Group between PRU 15 & PRN 15
all_columns = df.columns.tolist()
print(all_columns)

#Create 2 list of columns name for each group
pru_15_columns = ['NamaDUN', 'NAMA PDM', 'No Saluran', 'BN', 'PH', 'PN',
                  '%UP_BN_pru15', '%UP_PH_pru15', '%UP_PN_pru15']

prn_15_columns = ['NamaDUN', 'NAMA PDM', 'No Saluran', 'BN.1', 'PH.1', 'PN.1',
                  '%UP_BN_prn15', '%UP_PH_prn15', '%UP_PN_prn15']
# Out:
# ['ID', 'StatusPR', 'KodParlimen', 'NamaParlimen', 'KodDUN', 'NamaDUN', 'KodDM', 'NAMA PDM', 'No Saluran', 'Jum Undi PRU_15', 'PARTI MENANG pru_15', '%UP_BN_pru15', '%UP_PH_pru15', '%UP_PN_pru15', 'BN', 'PH', 'PN', 'Jum Undi PRN_15', 'PARTI MENANG prn_15', '%UP_BN_prn15', '%UP_PH_prn15', '%UP_PN_prn15', 'BN.1', 'PH.1', 'PN.1', 'JUM PENGUNDI (ALL KAUM)', 'MELAYU', 'CINA', 'INDIA', 'LAIN-LAIN']

# %% [markdown]
# ## Check the grouped datasets

# %%
pru15_df = df[pru_15_columns]
pru15_df.head()
# Out:
#    NamaDUN              NAMA PDM  No Saluran   BN   PH   PN %UP_BN_pru15  \
# 0      NaN              UNDI POS         NaN  599  168  299       55.90%
# 1  CHENNAH              UNDI POS         NaN  NaN  NaN  NaN          NaN
# 2  CHENNAH             UNDI AWAL         1.0   17    0    4       81.00%
# 3  CHENNAH  KAMPONG SUNGAI BULOH         1.0  202   65   97       55.30%
# 4  CHENNAH  KAMPONG SUNGAI BULOH         2.0  191   65  162       45.60%
#
#   %UP_PH_pru15 %UP_PN_pru15
# 0       15.70%       27.90%
# 1          NaN          NaN
# 2        0.00%       19.00%
# 3       17.80%       26.60%
# 4       15.50%       38.70%

# %%
prn15_df = df[prn_15_columns]
prn15_df.head()
# Out:
#    NamaDUN              NAMA PDM  No Saluran  BN.1 PH.1 PN.1 %UP_BN_prn15  \
# 0      NaN              UNDI POS         NaN   NaN  NaN  NaN          NaN
# 1  CHENNAH              UNDI POS         NaN   0.0   29   64        0.00%
# 2  CHENNAH             UNDI AWAL         1.0   0.0    9   20        0.00%
# 3  CHENNAH  KAMPONG SUNGAI BULOH         1.0   0.0  160  165        0.00%
# 4  CHENNAH  KAMPONG SUNGAI BULOH         2.0   0.0  118  229        0.00%
#
#   %UP_PH_prn15 %UP_PN_prn15
# 0          NaN          NaN
# 1       31.20%       68.80%
# 2       31.00%       69.00%
# 3       49.20%       50.80%
# 4       34.00%       66.00%

# %%
pru15_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1528 entries, 0 to 1527
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NamaDUN       1520 non-null   object
#  1   NAMA PDM      1528 non-null   object
#  2   No Saluran    1484 non-null   float64
#  3   BN            1395 non-null   object
#  4   PH            1395 non-null   object
#  5   PN            1395 non-null   object
#  6   %UP_BN_pru15  1395 non-null   object
#  7   %UP_PH_pru15  1395 non-null   object
#  8   %UP_PN_pru15  1395 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 107.6+ KB

# %%
prn15_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1528 entries, 0 to 1527
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NamaDUN       1520 non-null   object
#  1   NAMA PDM      1528 non-null   object
#  2   No Saluran    1484 non-null   float64
#  3   BN.1          1515 non-null   float64
#  4   PH.1          801 non-null    object
#  5   PN.1          1509 non-null   object
#  6   %UP_BN_prn15  1509 non-null   object
#  7   %UP_PH_prn15  1509 non-null   object
#  8   %UP_PN_prn15  1509 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 107.6+ KB

# %%
linggi_data = prn15_df[prn15_df['NamaDUN'] == "Linggi"]
total_bn_linggi = linggi_data['BN.1'].sum()
print(f"Total BN.1 votes for Linggi: {total_bn_linggi}")
# Out:
# Total BN.1 votes for Linggi: 0.0

# %% [markdown]
# # Check 'NaN' Values

# %% [markdown]
# # from group dataset 'pru_15df'

# %%
pru15_df.isna().sum()
# Out:
# NamaDUN           8
# NAMA PDM          0
# No Saluran       44
# BN              133
# PH              133
# PN              133
# %UP_BN_pru15    133
# %UP_PH_pru15    133
# %UP_PN_pru15    133
# dtype: int64

# %%
#Replace  'NaN' Values in columns
pru15_df[['%UP_BN_pru15', '%UP_PH_pru15', '%UP_PN_pru15']] = pru15_df[['%UP_BN_pru15', '%UP_PH_pru15', '%UP_PN_pru15']].fillna(0)
pru15_df
# Out:
# <ipython-input-17-6de9f8454ad9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pru15_df[['%UP_BN_pru15', '%UP_PH_pru15', '%UP_PN_pru15']] = pru15_df[['%UP_BN_pru15', '%UP_PH_pru15', '%UP_PN_pru15']].fillna(0)
#       NamaDUN              NAMA PDM  No Saluran   BN   PH   PN %UP_BN_pru15  \
# 0         NaN              UNDI POS         NaN  599  168  299       55.90%
# 1     CHENNAH              UNDI POS         NaN  NaN  NaN  NaN            0
# 2     CHENNAH             UNDI AWAL         1.0   17    0    4       81.00%
# 3     CHENNAH  KAMPONG SUNGAI BULOH         1.0  202   65   97       55.30%
# 4     CHENNAH  KAMPONG SUNGAI BULOH         2.0  191   65  162       45.60%
# ...

# %%
pru15_df[['No Saluran','BN', 'PH', 'PN', ]] = pru15_df[['No Saluran','BN', 'PH', 'PN', ]].fillna(0)
pru15_df
# Out:
# <ipython-input-18-4b7c4330b159>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pru15_df[['No Saluran','BN', 'PH', 'PN', ]] = pru15_df[['No Saluran','BN', 'PH', 'PN', ]].fillna(0)
#       NamaDUN              NAMA PDM  No Saluran   BN   PH   PN %UP_BN_pru15  \
# 0         NaN              UNDI POS         0.0  599  168  299       55.90%
# 1     CHENNAH              UNDI POS         0.0    0    0    0            0
# 2     CHENNAH             UNDI AWAL         1.0   17    0    4       81.00%
# 3     CHENNAH  KAMPONG SUNGAI BULOH         1.0  202   65   97       55.30%
# 4     CHENNAH  KAMPONG SUNGAI BULOH         2.0  191   65  162       45.60%
# ...       ...                   ...         ...  ...  ...  ...          ...
# ...

# %%
pru15_df.isna().sum()
# Out:
# NamaDUN         8
# NAMA PDM        0
# No Saluran      0
# BN              0
# PH              0
# PN              0
# %UP_BN_pru15    0
# %UP_PH_pru15    0
# %UP_PN_pru15    0
# dtype: int64

# %% [markdown]
# ## Check NaN values in variable 'NamaDUN'

# %%
nan_rows_NamaDUN = pru15_df[pru15_df['NamaDUN'].isna()].index.tolist()
nan_rows_NamaDUN
# Out:
# [0, 133, 307, 542, 740, 983, 1209, 1392]

# %% [markdown]
# ## Replace 'NaN' values and Fill with value below that rows then check again

# %%
pru15_df['NamaDUN'] = pru15_df['NamaDUN'].fillna(method= 'bfill')
pru15_df.isna().sum()
# Out:
# <ipython-input-21-5e66d988d8ac>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pru15_df['NamaDUN'] = pru15_df['NamaDUN'].fillna(method= 'bfill')
# <ipython-input-21-5e66d988d8ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pru15_df['NamaDUN'] = pru15_df['NamaDUN'].fillna(method= 'bfill')
# NamaDUN         0
# NAMA PDM        0
# No Saluran      0
# BN              0
# PH              0
# PN              0
# %UP_BN_pru15    0
# %UP_PH_pru15    0
# %UP_PN_pru15    0
# dtype: int64

# %% [markdown]
# # from group dataset 'prn15_df"

# %% [markdown]
# ## Check the NaN' values in dataset prn15_df

# %%
prn15_df.isna().sum()
# Out:
# NamaDUN           8
# NAMA PDM          0
# No Saluran       44
# BN.1             13
# PH.1            727
# PN.1             19
# %UP_BN_prn15     19
# %UP_PH_prn15     19
# %UP_PN_prn15     19
# dtype: int64

# %%
#Replace  'NaN' Values in columns
prn15_df[['No Saluran','%UP_BN_prn15', '%UP_PH_prn15', '%UP_PN_prn15', 'BN.1', 'PH.1', 'PN.1']] = prn15_df[['No Saluran', '%UP_BN_prn15', '%UP_PH_prn15', '%UP_PN_prn15', 'BN.1', 'PH.1', 'PN.1']].fillna(0)
prn15_df
# Out:
# <ipython-input-23-f8d64c1ce7dd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prn15_df[['No Saluran','%UP_BN_prn15', '%UP_PH_prn15', '%UP_PN_prn15', 'BN.1', 'PH.1', 'PN.1']] = prn15_df[['No Saluran', '%UP_BN_prn15', '%UP_PH_prn15', '%UP_PN_prn15', 'BN.1', 'PH.1', 'PN.1']].fillna(0)
#       NamaDUN              NAMA PDM  No Saluran  BN.1 PH.1 PN.1 %UP_BN_prn15  \
# 0         NaN              UNDI POS         0.0   0.0    0    0            0
# 1     CHENNAH              UNDI POS         0.0   0.0   29   64        0.00%
# 2     CHENNAH             UNDI AWAL         1.0   0.0    9   20        0.00%
# 3     CHENNAH  KAMPONG SUNGAI BULOH         1.0   0.0  160  165        0.00%
# ...

# %% [markdown]
# ## Check the 'NaN' Values

# %%
prn15_df.isna().sum()
# Out:
# NamaDUN         8
# NAMA PDM        0
# No Saluran      0
# BN.1            0
# PH.1            0
# PN.1            0
# %UP_BN_prn15    0
# %UP_PH_prn15    0
# %UP_PN_prn15    0
# dtype: int64

# %% [markdown]
# ## Replace 'NaN' values and Fill with value below that rows then check again

# %%
prn15_df['NamaDUN'] = prn15_df['NamaDUN'].fillna(method= 'bfill')
prn15_df.isna().sum()
# Out:
# <ipython-input-25-bbb45dda2ee3>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   prn15_df['NamaDUN'] = prn15_df['NamaDUN'].fillna(method= 'bfill')
# <ipython-input-25-bbb45dda2ee3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prn15_df['NamaDUN'] = prn15_df['NamaDUN'].fillna(method= 'bfill')
# NamaDUN         0
# NAMA PDM        0
# No Saluran      0
# BN.1            0
# PH.1            0
# PN.1            0
# %UP_BN_prn15    0
# %UP_PH_prn15    0
# %UP_PN_prn15    0
# dtype: int64

# %% [markdown]
# # Analysing the Datasets

# %% [markdown]
# ## 'pru15_df'

# %% [markdown]
# ### Support by Saluran

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pru15_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1528 entries, 0 to 1527
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NamaDUN       1528 non-null   object
#  1   NAMA PDM      1528 non-null   object
#  2   No Saluran    1528 non-null   float64
#  3   BN            1528 non-null   object
#  4   PH            1528 non-null   object
#  5   PN            1528 non-null   object
#  6   %UP_BN_pru15  1528 non-null   object
#  7   %UP_PH_pru15  1528 non-null   object
#  8   %UP_PN_pru15  1528 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 107.6+ KB

# %% [markdown]
# #### Stacked Bar Chart

# %%
# Group data by 'No Saluran' and sum votes for each party

# Convert 'No Saluran' to numeric, handling errors
pru15_df['No Saluran'] = pd.to_numeric(pru15_df['No Saluran'], errors='coerce')

# Convert 'BN', 'PH', and 'PN' to numeric before grouping
pru15_df[['BN', 'PH', 'PN']] = pru15_df[['BN', 'PH', 'PN']].apply(pd.to_numeric, errors='coerce')

# Replace NaN values with 0 after conversion
pru15_df['No Saluran'] = pru15_df['No Saluran'].fillna(0)


# Ensure 'No Saluran' is of type int or float
pru15_df['No Saluran'] = pru15_df['No Saluran'].astype(int) # You can use float if needed


stacked_data = pru15_df.groupby('No Saluran')[['BN', 'PH', 'PN']].sum().reset_index()

# Plot the stacked bar chart
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.bar(stacked_data['No Saluran'], stacked_data['BN'], label='BN', color= 'blue')
plt.bar(stacked_data['No Saluran'], stacked_data['PH'], bottom=stacked_data['BN'], label='PH', color= 'red')
plt.bar(stacked_data['No Saluran'], stacked_data['PN'], bottom=stacked_data['BN'] + stacked_data['PH'], label='PN', color= 'green')

plt.xlabel('No Saluran')
plt.ylabel('Total Votes')
plt.title('Stacked Bar Chart of Votes by Party and No Saluran (PRU 15)')
plt.legend()
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-28-969c830d2499>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pru15_df['No Saluran'] = pd.to_numeric(pru15_df['No Saluran'], errors='coerce')
# <ipython-input-28-969c830d2499>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pru15_df[['BN', 'PH', 'PN']] = pru15_df[['BN', 'PH', 'PN']].apply(pd.to_numeric, errors='coerce')
# <ipython-input-28-969c830d2499>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# #### Group Bar Chart

# %%
# Grouped Bar Chart


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd



# Group data by 'No Saluran' and sum votes for each party
grouped_data = pru15_df.groupby('No Saluran')[['BN', 'PH', 'PN']].sum().reset_index()

# Set the width of the bars
bar_width = 0.3

# Set the positions of the bars on the x-axis
r1 = np.arange(len(grouped_data))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Plot the grouped bar chart
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
plt.bar(r1, grouped_data['BN'], color='blue', width=bar_width, edgecolor='grey', label='BN')
plt.bar(r2, grouped_data['PH'], color='red', width=bar_width, edgecolor='grey', label='PH')
plt.bar(r3, grouped_data['PN'], color='green', width=bar_width, edgecolor='grey', label='PN')

plt.xlabel('No Saluran')
plt.ylabel('Total Votes')
plt.title('Grouped Bar Chart of Votes by Party and No Saluran PRU 15')
plt.xticks([r + bar_width for r in range(len(grouped_data))], grouped_data['No Saluran'], rotation=45, ha='right')

# Adjust spacing between x-axis ticks
plt.gca().xaxis.set_tick_params(width=1)  # Adjust tick width (try different values)
plt.subplots_adjust(bottom=0.2)  # Adjust bottom margin to accommodate rotated labels



plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Support By PDM

# %% [markdown]
# #### Total Votes among DUNs

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group data by 'NAMA PDM' and sum votes for each party
grouped_data_pdm = pru15_df.groupby('NamaDUN')[['BN', 'PH', 'PN']].sum().reset_index()

# Calculate total votes for each 'NAMA PDM'
grouped_data_pdm['Total Votes'] = grouped_data_pdm['BN'] + grouped_data_pdm['PH'] + grouped_data_pdm['PN']

# Sort by total votes in descending order (optional)
grouped_data_pdm = grouped_data_pdm.sort_values(by=['Total Votes'], ascending=False)

# Create the bar chart
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
plt.bar(grouped_data_pdm['NamaDUN'], grouped_data_pdm['Total Votes'], color='skyblue')  # You can change the color

plt.xlabel('NamaDUN')
plt.ylabel('Total Votes')
plt.title('Total Votes Density among DUNs PRU 15')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Bar Chart

# %% [markdown]
# ##### Distributions of Votes by Parties Among DUNs (Bar Chart)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group data by 'NamaDUN' and sum votes for each party
grouped_data = pru15_df.groupby('NamaDUN')[['BN', 'PH', 'PN']].sum().reset_index()

# Plot the stacked bar chart
plt.figure(figsize=(12, 6))  # Adjust figure size as needed

# Stacked bars for each party
plt.bar(grouped_data['NamaDUN'], grouped_data['BN'], label='BN', color='blue')
plt.bar(grouped_data['NamaDUN'], grouped_data['PH'], bottom=grouped_data['BN'], label='PH', color='red')
plt.bar(grouped_data['NamaDUN'], grouped_data['PN'], bottom=grouped_data['BN'] + grouped_data['PH'], label='PN', color='green')

plt.xlabel('NamaDUN')
plt.ylabel('Total Votes')
plt.title('Total Votes Density among DUNs by Party PRU 15')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 'Total Votes Density among NamaDUN by Party (Grouped Bar Chart)')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Group data by 'NamaDUN' and sum votes for each party
grouped_data = pru15_df.groupby('NamaDUN')[['BN', 'PH', 'PN']].sum().reset_index()

# Set the width of the bars
bar_width = 0.25

# Set the positions of the bars on the x-axis
r1 = np.arange(len(grouped_data))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Plot the grouped bar chart with custom colors and wider bars
plt.figure(figsize=(15, 6))  # Adjust figure size as needed
plt.bar(r1, grouped_data['BN'], color='blue', width=bar_width, edgecolor='grey', label='BN')
plt.bar(r2, grouped_data['PH'], color='red', width=bar_width, edgecolor='grey', label='PH')
plt.bar(r3, grouped_data['PN'], color='green', width=bar_width, edgecolor='grey', label='PN')

plt.xlabel('NamaDUN')
plt.ylabel('Total Votes')
plt.title('Total Votes Density among DUNs by Party PRU 15 (Grouped Bar Chart)')
plt.xticks([r + bar_width for r in range(len(grouped_data))], grouped_data['NamaDUN'], rotation=90, ha='right')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Treemap Chart

# %% [markdown]
# ##### 'Total Votes Density among NamaDUN (Treemap)

# %%
# !pip install squarify
import squarify
import matplotlib.pyplot as plt
import pandas as pd

# Group data by 'NamaDUN' and sum votes for each party
grouped_data = pru15_df.groupby('NamaDUN')[['BN', 'PH', 'PN']].sum().reset_index()

# Calculate total votes for each 'NamaDUN'
grouped_data['Total Votes'] = grouped_data['BN'] + grouped_data['PH'] + grouped_data['PN']

# Create a list of labels for each rectangle
labels = [f"{name}\nTotal Votes: {votes}" for name, votes in zip(grouped_data['NamaDUN'], grouped_data['Total Votes'])]

# Create the treemap
plt.figure(figsize=(12, 8))  # Adjust figure size as needed
squarify.plot(sizes=grouped_data['Total Votes'], label=labels, alpha=.8)
plt.axis('off')  # Hide axes
plt.title('Total Votes Density among NamaDUN (Treemap)')
plt.show()

# %% [markdown]
# ##### Popular Votes & Total Votes Density among NamaDUN (Treemap)

# %%
# !pip install squarify
import squarify
import matplotlib.pyplot as plt
import pandas as pd

# Group data by 'NamaDUN' and sum votes for each party
grouped_data = pru15_df.groupby('NamaDUN')[['BN', 'PH', 'PN']].sum().reset_index()

# Calculate total votes for each 'NamaDUN'
grouped_data['Total Votes'] = grouped_data['BN'] + grouped_data['PH'] + grouped_data['PN']

# Create a list of labels for each rectangle
labels = [f"{name}\nTotal Votes: {votes}" for name, votes in zip(grouped_data['NamaDUN'], grouped_data['Total Votes'])]

# Create the treemap
plt.figure(figsize=(12, 8))  # Adjust figure size as needed
ax = squarify.plot(sizes=grouped_data['Total Votes'], label=labels, alpha=.8)

# --- Adding Legend for Party Percentages ---
# Calculate percentages for each party
total_votes = grouped_data['Total Votes'].sum()
bn_percent = (grouped_data['BN'].sum() / total_votes) * 100
ph_percent = (grouped_data['PH'].sum() / total_votes) * 100
pn_percent = (grouped_data['PN'].sum() / total_votes) * 100

# Create legend handles and labels
handles = [
    plt.Rectangle((0, 0), 1, 1, color='blue'),  # Assuming BN is blue
    plt.Rectangle((0, 0), 1, 1, color='red'),   # Assuming PH is red
    plt.Rectangle((0, 0), 1, 1, color='green')  # Assuming PN is green
]
labels = [
    f"BN: {bn_percent:.1f}%",
    f"PH: {ph_percent:.1f}%",
    f"PN: {pn_percent:.1f}%"
]

# Add legend to the plot
plt.legend(handles, labels, title="Party Percentages", loc="upper right")
# --- End of Legend Addition ---

plt.axis('off')  # Hide axes
plt.title('Total Votes Density among DUN PRU 15 (Treemap)')
plt.show()

# %% [markdown]
# #### Bubble Chart

# %% [markdown]
# ##### Total Votes Density and BN Percentage among NamaDUN (Bubble Chart)

# %%
# !pip install adjustText

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from adjustText import adjust_text  # Import adjust_text
import matplotlib.colors as mcolors # for colors management

# ... (Your existing code to prepare grouped_data) ...

# Group data by 'NamaDUN' and sum votes for each party
grouped_data = pru15_df.groupby('NamaDUN')[['BN', 'PH', 'PN']].sum().reset_index()

# Calculate total votes for each 'NamaDUN'
grouped_data['Total Votes'] = grouped_data['BN'] + grouped_data['PH'] + grouped_data['PN']

# Calculate percentage for each party in each NamaDUN
grouped_data['BN Percentage'] = (grouped_data['BN'] / grouped_data['Total Votes']) * 100
grouped_data['PH Percentage'] = (grouped_data['PH'] / grouped_data['Total Votes']) * 100
grouped_data['PN Percentage'] = (grouped_data['PN'] / grouped_data['Total Votes']) * 100

# Filter data for NamaDUN where BN is dominant
# This line is added to create the bn_dominant_data DataFrame
bn_dominant_data = grouped_data[grouped_data['BN Percentage'] > grouped_data[['PH Percentage', 'PN Percentage']].max(axis=1)]



# Create a custom colormap
colors = ['white', 'lightblue', 'skyblue', 'deepskyblue', 'royalblue', 'navy']  # Adjust colors as desired
cmap = mcolors.LinearSegmentedColormap.from_list('bn_cmap', colors)

# Create the bubble chart
plt.figure(figsize=(12, 8))

# Scatter plot with color based on 'BN Percentage' and custom colormap
scatter = plt.scatter(
    x=bn_dominant_data['NamaDUN'],
    y=bn_dominant_data['Total Votes'],
    s=bn_dominant_data['Total Votes'] * 5,  # Scale bubble size
    c=bn_dominant_data['BN Percentage'],  # Color by BN Percentage
    cmap=cmap,  # Use custom colormap
    alpha=0.7  # Adjust transparency
)

plt.xlabel('NamaDUN')
plt.ylabel('Total Votes')
plt.title('Total Votes Density and BN Percentage among NamaDUN (Bubble Chart- PRU 15)')
plt.xticks(rotation=90, ha='right')

# Add colorbar for BN Percentage with custom colormap
cbar = plt.colorbar(scatter)
cbar.set_label('BN Percentage (%)')

# --- Add annotations and adjust for overlap ---
texts = []
for i, row in bn_dominant_data.iterrows():
    # Annotate with NamaDUN name and BN percentage outside the bubble
    label = f"{row['NamaDUN']} ({row['BN Percentage']:.1f}%)" # Combine NamaDUN and percentage
    texts.append(plt.text(row['NamaDUN'], row['Total Votes'] + row['Total Votes'] * 0.1,  # Adjust vertical position
                          label,  # Use combined label
                          ha='center', va='bottom', fontsize=6, color='black'))  # Smaller font size

    # Annotate with percentages inside the bubble (optional)
    # You can comment this out if you only want NamaDUN labels outside
    # texts.append(plt.text(row['NamaDUN'], row['Total Votes'] + row['Total Votes'] * 0.05,
    #                       f"BN: {row['BN Percentage']:.1f}%\nPH: {row['PH Percentage']:.1f}%\nPN: {row['PN Percentage']:.1f}%",
    #                       ha='center', va='center', fontsize=5, color='black'))  # Even smaller font size

 # Use adjust_text to prevent overlap with adjustments
adjust_text(texts,
            arrowprops=dict(arrowstyle='-', color='gray', lw=0.5),  # Use lines instead of arrows
            autoalign='xy',  # Auto-align text
            only_overlaps=True,  # Only adjust overlapping text
            force_text=(0.1, 0.25),  # Adjust text position more aggressively
            force_points=(0.2, 0.5),  # Adjust point positions less aggressively
            expand_text=(1.05, 1.2),  # Expand text area slightly
            expand_points=(1.05, 1.2)  # Expand point area slightly
            )

# --- End of annotations and adjustment ---

plt.tight_layout()
plt.show()
# Out:
# ...
# WARNING:adjustText:Looks like you are using a tranform that doesn't support FancyArrowPatch, using ax.annotate instead. The arrows might strike through texts. Increasing shrinkA in arrowprops might help.

# %% [markdown]
# ##### Total Votes Density and BN Percentage among NamaDUN (Bubble Chart 2)

# %%
# !pip install adjustText
# !pip install matplotlib

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from adjustText import adjust_text  # Import adjust_text
import matplotlib.colors as mcolors  # Import mcolors for color management

# ... (Your existing code to prepare grouped_data) ...

# Group data by 'NamaDUN' and sum votes for each party
grouped_data = pru15_df.groupby('NamaDUN')[['BN', 'PH', 'PN']].sum().reset_index()

# Calculate total votes for each 'NamaDUN'
grouped_data['Total Votes'] = grouped_data['BN'] + grouped_data['PH'] + grouped_data['PN']

# Calculate percentage for each party in each NamaDUN
grouped_data['BN Percentage'] = (grouped_data['BN'] / grouped_data['Total Votes']) * 100
grouped_data['PH Percentage'] = (grouped_data['PH'] / grouped_data['Total Votes']) * 100
grouped_data['PN Percentage'] = (grouped_data['PN'] / grouped_data['Total Votes']) * 100

# Filter data for NamaDUN where BN is dominant
bn_dominant_data = grouped_data[grouped_data['BN Percentage'] > grouped_data[['PH Percentage', 'PN Percentage']].max(axis=1)]

# Sort data by 'BN Percentage' in ascending order
bn_dominant_data = bn_dominant_data.sort_values(by=['BN Percentage'], ascending=True)


# Create a custom colormap
colors = ['white', 'lightblue', 'skyblue', 'deepskyblue', 'royalblue', 'navy']  # Adjust colors as desired
cmap = mcolors.LinearSegmentedColormap.from_list('bn_cmap', colors)

# Create the bubble chart
plt.figure(figsize=(12, 8))

# Scatter plot with color based on 'BN Percentage' and custom colormap, sorted by percentage
scatter = plt.scatter(
    x=bn_dominant_data['NamaDUN'],
    y=bn_dominant_data['Total Votes'],
    s=bn_dominant_data['BN Percentage'] * 10,  # Bubble size scaled by BN Percentage
    c=bn_dominant_data['BN Percentage'],  # Color by BN Percentage
    cmap=cmap,  # Use custom colormap
    alpha=0.7  # Adjust transparency
)

plt.xlabel('NamaDUN')
plt.ylabel('Total Votes')
plt.title('Total Votes Density and BN Percentage among NamaDUN (Bubble Chart- PRU 15)')
plt.xticks(rotation=90, ha='right')

# Add colorbar for BN Percentage with custom colormap
cbar = plt.colorbar(scatter)
cbar.set_label('BN Percentage (%)')

# --- Add annotations and adjust for overlap ---
texts = []
for i, row in bn_dominant_data.iterrows():
    # Annotate with NamaDUN name and BN percentage outside the bubble
    label = f"{row['NamaDUN']} ({row['BN Percentage']:.1f}%)"  # Combine NamaDUN and percentage
    texts.append(plt.text(row['NamaDUN'], row['Total Votes'] + row['Total Votes'] * 0.1,  # Adjust vertical position
                          label,  # Use combined label
                          ha='center', va='bottom', fontsize=6, color='black'))  # Smaller font size


# Use adjust_text to prevent overlap with adjustments
adjust_text(texts,
            arrowprops=dict(arrowstyle='-', color='gray', lw=0.5),  # Use lines instead of arrows
            autoalign='xy',  # Auto-align text
            only_overlaps=True,  # Only adjust overlapping text
            force_text=(0.1, 0.25),  # Adjust text position more aggressively
            force_points=(0.2, 0.5),  # Adjust point positions less aggressively
            expand_text=(1.05, 1.2),  # Expand text area slightly
            expand_points=(1.05, 1.2)  # Expand point area slightly
            )

# --- End of annotations and adjustment ---

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Total Votes Density and BN Percentage among NamaDUN (Bubble Chart 3)

# %%
# !pip install adjustText
# !pip install matplotlib

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from adjustText import adjust_text  # Import adjust_text
import matplotlib.colors as mcolors  # Import mcolors for color management

# ... (Your existing code to prepare grouped_data) ...

# Group data by 'NamaDUN' and sum votes for each party
grouped_data = pru15_df.groupby('NamaDUN')[['BN', 'PH', 'PN']].sum().reset_index()

# Calculate total votes for each 'NamaDUN'
grouped_data['Total Votes'] = grouped_data['BN'] + grouped_data['PH'] + grouped_data['PN']

# Calculate percentage for each party in each NamaDUN
grouped_data['BN Percentage'] = (grouped_data['BN'] / grouped_data['Total Votes']) * 100
grouped_data['PH Percentage'] = (grouped_data['PH'] / grouped_data['Total Votes']) * 100
grouped_data['PN Percentage'] = (grouped_data['PN'] / grouped_data['Total Votes']) * 100

# Filter data for NamaDUN where BN is dominant
bn_dominant_data = grouped_data[grouped_data['BN Percentage'] > grouped_data[['PH Percentage', 'PN Percentage']].max(axis=1)]

# Sort data by 'BN Percentage' in ascending order
bn_dominant_data = bn_dominant_data.sort_values(by=['BN Percentage'], ascending=True)


# Create a custom colormap
colors = ['grey', 'orange', 'yellow', 'green', 'royalblue', 'navy']  # Adjust colors as desired
cmap = mcolors.LinearSegmentedColormap.from_list('bn_cmap', colors)

# Create the bubble chart
fig, ax = plt.subplots(figsize=(12, 8))  # Create fig and ax objects

# Scatter plot with color based on 'BN Percentage' and custom colormap, sorted by percentage
scatter = ax.scatter(  # Use ax.scatter instead of plt.scatter
    x=bn_dominant_data['NamaDUN'],
    y=bn_dominant_data['Total Votes'],
    s=bn_dominant_data['BN Percentage'] * 10,  # Bubble size scaled by BN Percentage
    c=bn_dominant_data['BN Percentage'],  # Color by BN Percentage
    cmap=cmap,  # Use custom colormap
    alpha=0.7  # Adjust transparency
)

ax.set_xlabel('NamaDUN')
ax.set_ylabel('Total Votes')
ax.set_title('Total Votes Density and BN Percentage among NamaDUN (Bubble Chart- PRU 15)')
ax.set_xticks(ax.get_xticks())  # Get current x-tick positions
ax.set_xticklabels(bn_dominant_data['NamaDUN'], rotation=90, ha='right')

# Add colorbar for BN Percentage with custom colormap
cbar = fig.colorbar(scatter, ax=ax)  # Use fig.colorbar and specify ax
cbar.set_label('BN Percentage (%)')

# --- Add annotations and adjust for overlap ---
texts = []
for i, row in bn_dominant_data.iterrows():
    # Annotate with NamaDUN name and BN percentage outside the bubble
    label = f"{row['NamaDUN']} ({row['BN Percentage']:.1f}%)"  # Combine NamaDUN and percentage
    texts.append(ax.text(row['NamaDUN'], row['Total Votes'] + row['Total Votes'] * 0.1,  # Adjust vertical position
                          label,  # Use combined label
                          ha='center', va='bottom', fontsize=6, color='black'))  # Smaller font size


# Use adjust_text to prevent overlap with adjustments
adjust_text(texts,
            arrowprops=dict(arrowstyle='-', color='gray', lw=0.5),  # Use lines instead of arrows
            autoalign='xy',  # Auto-align text
            only_overlaps=True,  # Only adjust overlapping text
            force_text=(0.1, 0.25),  # Adjust text position more aggressively
            force_points=(0.2, 0.5),  # Adjust point positions less aggressively
            expand_text=(1.05, 1.2),  # Expand text area slightly
            expand_points=(1.05, 1.2)  # Expand point area slightly
            )

# --- End of annotations and adjustment ---

# Add grid for better readability
ax.grid(True, linestyle='--', alpha=0.5)  # Add gridlines

# Adjust axis limits if needed (optional)
# ax.set_xlim([-1, len(bn_dominant_data)])  # Adjust x-axis limits
# ax.set_ylim([0, bn_dominant_data['Total Votes'].max() * 1.1])  # Adjust y-axis limits

# Add a more insightful title (optional)
# ax.set_title('BN Dominance in NamaDUN by Total Votes and Percentage (PRU15)', fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 'prn15_df'

# %%
prn15_df.isna().sum()
# Out:
# NamaDUN         0
# NAMA PDM        0
# No Saluran      0
# BN.1            0
# PH.1            0
# PN.1            0
# %UP_BN_prn15    0
# %UP_PH_prn15    0
# %UP_PN_prn15    0
# dtype: int64

# %% [markdown]
# ### Support by Saluran

# %% [markdown]
# #### Stacked Bar Chart

# %%
# Group data by 'No Saluran' and sum votes for each party

# Convert 'No Saluran' to numeric, handling errors
prn15_df['No Saluran'] = pd.to_numeric(prn15_df['No Saluran'], errors='coerce')

# Convert 'BN', 'PH', and 'PN' to numeric before grouping
prn15_df[['BN.1', 'PH.1', 'PN.1']] = prn15_df[['BN.1', 'PH.1', 'PN.1']].apply(pd.to_numeric, errors='coerce')

# Replace NaN values with 0 after conversion
prn15_df['No Saluran'] = prn15_df['No Saluran'].fillna(0)


# Ensure 'No Saluran' is of type int or float
prn15_df['No Saluran'] = prn15_df['No Saluran'].astype(int) # You can use float if needed


stacked_data = prn15_df.groupby('No Saluran')[['BN.1', 'PH.1', 'PN.1']].sum().reset_index()

# Plot the stacked bar chart
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.bar(stacked_data['No Saluran'], stacked_data['BN.1'], label='BN', color= 'blue')
plt.bar(stacked_data['No Saluran'], stacked_data['PH.1'], bottom=stacked_data['BN.1'], label='PH', color= 'red')
plt.bar(stacked_data['No Saluran'], stacked_data['PN.1'], bottom=stacked_data['BN.1'] + stacked_data['PH.1'], label='PN', color= 'green')

plt.xlabel('No Saluran')
plt.ylabel('Total Votes')
plt.title('Stacked Bar Chart of Votes by Party and No Saluran (PRN 15)')
plt.legend()
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-38-dba4ba7b89dc>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prn15_df['No Saluran'] = pd.to_numeric(prn15_df['No Saluran'], errors='coerce')
# <ipython-input-38-dba4ba7b89dc>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prn15_df[['BN.1', 'PH.1', 'PN.1']] = prn15_df[['BN.1', 'PH.1', 'PN.1']].apply(pd.to_numeric, errors='coerce')
# <ipython-input-38-dba4ba7b89dc>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# #### Group Bar Chart

# %%
# Grouped Bar Chart


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd



# Group data by 'No Saluran' and sum votes for each party
grouped_data = prn15_df.groupby('No Saluran')[['BN.1', 'PH.1', 'PN.1']].sum().reset_index()

# Set the width of the bars
bar_width = 0.3

# Set the positions of the bars on the x-axis
r1 = np.arange(len(grouped_data))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Plot the grouped bar chart
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
plt.bar(r1, grouped_data['BN.1'], color='blue', width=bar_width, edgecolor='grey', label='BN')
plt.bar(r2, grouped_data['PH.1'], color='red', width=bar_width, edgecolor='grey', label='PH')
plt.bar(r3, grouped_data['PN.1'], color='green', width=bar_width, edgecolor='grey', label='PN')

plt.xlabel('No Saluran')
plt.ylabel('Total Votes')
plt.title('Grouped Bar Chart of Votes by Party and No Saluran (PRN 15)')
plt.xticks([r + bar_width for r in range(len(grouped_data))], grouped_data['No Saluran'], rotation=45, ha='right')

# Adjust spacing between x-axis ticks
plt.gca().xaxis.set_tick_params(width=1)  # Adjust tick width (try different values)
plt.subplots_adjust(bottom=0.2)  # Adjust bottom margin to accommodate rotated labels



plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Support by PDM

# %% [markdown]
# #### Total Votes by PDM

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group data by 'NAMA PDM' and sum votes for each party
grouped_data_pdm = prn15_df.groupby('NamaDUN')[['BN.1', 'PH.1', 'PN.1']].sum().reset_index()

# Calculate total votes for each 'NAMA PDM'
grouped_data_pdm['Total Votes'] = grouped_data_pdm['BN.1'] + grouped_data_pdm['PH.1'] + grouped_data_pdm['PN.1']

# Sort by total votes in descending order (optional)
grouped_data_pdm = grouped_data_pdm.sort_values(by=['Total Votes'], ascending=False)

# Create the bar chart
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
plt.bar(grouped_data_pdm['NamaDUN'], grouped_data_pdm['Total Votes'], color='blue')  # You can change the color

plt.xlabel('NamaDUN')
plt.ylabel('Total Votes')
plt.title('Total Votes Density among DUNs PRN 15')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Bar Chart

# %% [markdown]
# ##### Distributions of Votes by parties among DUNs

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group data by 'NamaDUN' and sum votes for each party
grouped_data = prn15_df.groupby('NamaDUN')[['BN.1', 'PH.1', 'PN.1']].sum().reset_index()

# Plot the stacked bar chart
plt.figure(figsize=(12, 6))  # Adjust figure size as needed

# Stacked bars for each party
plt.bar(grouped_data['NamaDUN'], grouped_data['BN.1'], label='BN', color='blue')
plt.bar(grouped_data['NamaDUN'], grouped_data['PH.1'], bottom=grouped_data['BN.1'], label='PH', color='red')
plt.bar(grouped_data['NamaDUN'], grouped_data['PN.1'], bottom=grouped_data['BN.1'] + grouped_data['PH.1'], label='PN', color='green')

plt.xlabel('NamaDUN')
plt.ylabel('Total Votes')
plt.title('Total Votes Density among DUNs by Party (PRN 15)')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Group Bar Chart

# %% [markdown]
# ##### Distributions of Votes by parties among DUNs (Group Bar Chart)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Group data by 'NamaDUN' and sum votes for each party
grouped_data = prn15_df.groupby('NamaDUN')[['BN.1', 'PH.1', 'PN.1']].sum().reset_index()

# Set the width of the bars
bar_width = 0.25

# Set the positions of the bars on the x-axis
r1 = np.arange(len(grouped_data))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Plot the grouped bar chart with custom colors and wider bars
plt.figure(figsize=(15, 6))  # Adjust figure size as needed
plt.bar(r1, grouped_data['BN.1'], color='blue', width=bar_width, edgecolor='grey', label='BN')
plt.bar(r2, grouped_data['PH.1'], color='red', width=bar_width, edgecolor='grey', label='PH')
plt.bar(r3, grouped_data['PN.1'], color='green', width=bar_width, edgecolor='grey', label='PN')

plt.xlabel('NamaDUN')
plt.ylabel('Total Votes')
plt.title('Total Votes Density among DUNs by Party PRN 15 (Grouped Bar Chart)')
plt.xticks([r + bar_width for r in range(len(grouped_data))], grouped_data['NamaDUN'], rotation=90, ha='right')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Treemap Chart

# %% [markdown]
# ##### Popular Votes & Total Votes Density among NamaDUN (Treemap)

# %%
# !pip install squarify
import squarify
import matplotlib.pyplot as plt
import pandas as pd

# Group data by 'NamaDUN' and sum votes for each party
grouped_data = prn15_df.groupby('NamaDUN')[['BN.1', 'PH.1', 'PN.1']].sum().reset_index()

# Calculate total votes for each 'NamaDUN'
grouped_data['Total Votes'] = grouped_data['BN.1'] + grouped_data['PH.1'] + grouped_data['PN.1']

# Create a list of labels for each rectangle
labels = [f"{name}\nTotal Votes: {votes}" for name, votes in zip(grouped_data['NamaDUN'], grouped_data['Total Votes'])]

# Create the treemap
plt.figure(figsize=(12, 8))  # Adjust figure size as needed
ax = squarify.plot(sizes=grouped_data['Total Votes'], label=labels, alpha=.8)

# --- Adding Legend for Party Percentages ---
# Calculate percentages for each party
total_votes = grouped_data['Total Votes'].sum()
bn_percent = (grouped_data['BN.1'].sum() / total_votes) * 100
ph_percent = (grouped_data['PH.1'].sum() / total_votes) * 100
pn_percent = (grouped_data['PN.1'].sum() / total_votes) * 100

# Create legend handles and labels
handles = [
    plt.Rectangle((0, 0), 1, 1, color='blue'),  # Assuming BN is blue
    plt.Rectangle((0, 0), 1, 1, color='red'),   # Assuming PH is red
    plt.Rectangle((0, 0), 1, 1, color='green')  # Assuming PN is green
]
labels = [
    f"BN: {bn_percent:.1f}%",
    f"PH: {ph_percent:.1f}%",
    f"PN: {pn_percent:.1f}%"
]

# Add legend to the plot
plt.legend(handles, labels, title="Party Percentages", loc="upper right")
# --- End of Legend Addition ---

plt.axis('off')  # Hide axes
plt.title('Total Votes Density among DUN PRN 15 (Treemap)')
plt.show()

# %% [markdown]
# #### Bubble Chart

# %%
# !pip install adjustText
# !pip install matplotlib

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from adjustText import adjust_text  # Import adjust_text
import matplotlib.colors as mcolors  # Import mcolors for color management

# ... (Your existing code to prepare grouped_data) ...

# Group data by 'NamaDUN' and sum votes for each party
grouped_data = prn15_df.groupby('NamaDUN')[['BN.1', 'PH.1', 'PN.1']].sum().reset_index()

# Calculate total votes for each 'NamaDUN'
grouped_data['Total Votes'] = grouped_data['BN.1'] + grouped_data['PH.1'] + grouped_data['PN.1']

# Calculate percentage for each party in each NamaDUN
grouped_data['BN Percentage'] = (grouped_data['BN.1'] / grouped_data['Total Votes']) * 100
grouped_data['PH Percentage'] = (grouped_data['PH.1'] / grouped_data['Total Votes']) * 100
grouped_data['PN Percentage'] = (grouped_data['PN.1'] / grouped_data['Total Votes']) * 100

# Filter data for NamaDUN where BN is dominant
bn_dominant_data = grouped_data[grouped_data['BN Percentage'] > grouped_data[['PH Percentage', 'PN Percentage']].max(axis=1)]
print('Paroi' in bn_dominant_data['NamaDUN'].values)

# Sort data by 'BN Percentage' in ascending order
bn_dominant_data = bn_dominant_data.sort_values(by=['BN Percentage'], ascending=True)

# Create a custom colormap
colors = ['grey', 'orange', 'yellow', 'green', 'royalblue', 'navy']  # Adjust colors as desired
cmap = mcolors.LinearSegmentedColormap.from_list('bn_cmap', colors)

print(grouped_data[grouped_data['NamaDUN'] == 'Paroi'])
# Create the bubble chart
fig, ax = plt.subplots(figsize=(12, 8))  # Create fig and ax objects

# Scatter plot with color based on 'BN Percentage' and custom colormap, sorted by percentage
scatter = ax.scatter(  # Use ax.scatter instead of plt.scatter
    x=bn_dominant_data['NamaDUN'],
    y=bn_dominant_data['Total Votes'],
    s=bn_dominant_data['BN Percentage'] * 10,  # Bubble size scaled by BN Percentage
    c=bn_dominant_data['BN Percentage'],  # Color by BN Percentage
    cmap=cmap,  # Use custom colormap
    alpha=0.7  # Adjust transparency
)

ax.set_xlabel('NamaDUN')
ax.set_ylabel('Total Votes')
ax.set_title('Total Votes Density and BN Percentage among DUNs (Bubble Chart- PRN 15)')
ax.set_xticks(ax.get_xticks())  # Get current x-tick positions
ax.set_xticklabels(bn_dominant_data['NamaDUN'], rotation=90, ha='right')

# Add colorbar for BN Percentage with custom colormap
cbar = fig.colorbar(scatter, ax=ax)  # Use fig.colorbar and specify ax
cbar.set_label('BN Percentage (%)')

# --- Add annotations and adjust for overlap ---
texts = []
for i, row in bn_dominant_data.iterrows():
    # Annotate with NamaDUN name and BN percentage outside the bubble
    label = f"{row['NamaDUN']} ({row['BN Percentage']:.1f}%)"  # Combine NamaDUN and percentage
    texts.append(ax.text(row['NamaDUN'], row['Total Votes'] + row['Total Votes'] * 0.1,  # Adjust vertical position
                          label,  # Use combined label
                          ha='center', va='bottom', fontsize=6, color='black'))  # Smaller font size


# Use adjust_text to prevent overlap with adjustments
adjust_text(texts,
            arrowprops=dict(arrowstyle='-', color='gray', lw=0.5),  # Use lines instead of arrows
            autoalign='xy',  # Auto-align text
            only_overlaps=True,  # Only adjust overlapping text
            force_text=(0.1, 0.25),  # Adjust text position more aggressively
            force_points=(0.2, 0.5),  # Adjust point positions less aggressively
            expand_text=(1.05, 1.2),  # Expand text area slightly
            expand_points=(1.05, 1.2)  # Expand point area slightly
            )

# --- End of annotations and adjustment ---

# Add grid for better readability
ax.grid(True, linestyle='--', alpha=0.5)  # Add gridlines

# Adjust axis limits if needed (optional)
# ax.set_xlim([-1, len(bn_dominant_data)])  # Adjust x-axis limits
# ax.set_ylim([0, bn_dominant_data['Total Votes'].max() * 1.1])  # Adjust y-axis limits

# Add a more insightful title (optional)
# ax.set_title('BN Dominance in NamaDUN by Total Votes and Percentage (PRU15)', fontsize=14)

plt.tight_layout()
plt.show()
# Out:
# ...
# False
# Empty DataFrame
# Columns: [NamaDUN, BN.1, PH.1, PN.1, Total Votes, BN Percentage, PH Percentage, PN Percentage]
# Index: []
